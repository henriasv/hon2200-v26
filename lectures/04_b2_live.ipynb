# %%
import numpy as np
data = np.loadtxt("data/hemmelig_funksjon.txt")
x = data[:,0]
y = data[:,1]

indices = np.random.permutation(len(x))
idx_train, idx_validate = np.array_split(indices, 2)
x_train = x[idx_train]
y_train = y[idx_train]
x_validate = x[idx_validate]
y_validate = y[idx_validate]

# %%
print(indices)
len(indices)
# Out:
# [67 19  0  5 69 25 43 87 97 12  7 70 86 65 58 28 72 71 24 17 18 54 23 42
#   6 60 52 59 29 38 48 55 85 10 31 96 91 62  3  4 14 21 44 37 39 53 92 34
#  80 50 45 36 77 79 30 41 46  2 64 27 56 22 90 88 76  9 51 66 20 74 83 33
#  95 40 61 47 93 98 57 35 89 26 75 84 81 32 63 16 99  1 11 94 73  8 68 82
#  49 78 15 13]
# 100
